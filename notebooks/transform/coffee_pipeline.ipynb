# %% [markdown]
# # Data Preprocessing

# %%
# libraries
# data load

# %% [markdown]
# ## Data Validation

# %%
# Drop Columns
# Data Format
# Drop Duplicates

# %% [markdown]
# ## Outlier Detection

# %%
# SD Method
# MADe Method
# Z-score
# Modified Z-score
# Interquartile Range

# MCD Method
# Elliptic Envelope

# %% [markdown]
# ## Feature Engineering

# %%
# Create Features
# Feature Analysis

# %% [markdown]
# ## Feature Selection

# %%
# Variance Threshold
# Mutual Information

# %% [markdown]
# # Data Pipeline

# %% [markdown]
# ## Hold-Out Method

# %% [markdown]
# ## Create Pipeline

# %% [markdown]
# ## Display Pipeline

# %% [markdown]
# ## Save Pipeline

# %% [markdown]
# ## Test Pipeline
